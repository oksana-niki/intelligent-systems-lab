# %% [markdown]
# ```mermaid
# flowchart TD
#     %% Название
#     Center["Директор"]
#
#     %% Уровень 1
#     MedDiag["Медико-диагностическое<br>отделение"]
#     LFK["Отдел ЛФК и<br>физиотерапии"]
#     TsrDept["Отдел ТСР и<br>эрготерапии"]
#     PsychDept["Психолого-педагогическая<br>служба"]
#     SocialDept["Социально-юридическая<br>служба"]
#     MedServ["Медицинская служба"]
#
#     Center --> MedDiag
#     Center --> LFK
#     Center --> TsrDept
#     Center --> PsychDept
#     Center --> SocialDept
#     Center --> MedServ
#
#     %% Медико-диагностическое отделение
#     Neurologist["Детский невролог"]
#     Orthopedist["Ортопед"]
#     Rehabilitator["Реабилитолог"]
#     MedDiag --> Neurologist
#     MedDiag --> Orthopedist
#     MedDiag --> Rehabilitator
#
#     %% ЛФК
#     LFKDoctor["Врач ЛФК"]
#     Instructors["Инструкторы"]
#     LFK --> LFKDoctor
#     LFK --> Instructors
#
#     %% ТСР и эрготерапия
#     Ergo["Эрготерапевт"]
#     Engineer["Инженер по ТСР"]
#     Consultant["Технический консультант"]
#     TsrDept --> Ergo
#     TsrDept --> Engineer
#     TsrDept --> Consultant
#
#     %% Психолого-педагогическая служба
#     Psychologist["Психолог"]
#     Speech["Логопед / дефектолог"]
#     PsychDept --> Psychologist
#     PsychDept --> Speech
#
#     %% Социально-юридическая служба
#     SocialWorker["Социальный работник"]
#     SocialDept --> SocialWorker
#
#     %% Медицинская служба
#     Nurses["Медсёстры"]
#     CareAssistants["Помощники по уходу"]
#     MedServ --> Nurses
#     MedServ --> CareAssistants
# ```

# %% [markdown]
# ```mermaid
# flowchart LR
#     %% Название
#     Center["Директор"]
#
#     %% Уровень 1
#     MedDiag["Медико-диагностическое<br>отделение"]
#     LFK["Отдел ЛФК и<br>физиотерапии"]
#     TsrDept["Отдел ТСР и<br>эрготерапии"]
#     PsychDept["Психолого-педагогическая<br>служба"]
#     SocialDept["Социально-юридическая<br>служба"]
#     MedServ["Медицинская служба"]
#
#     Center --> MedDiag
#     Center --> LFK
#     Center --> TsrDept
#     Center --> PsychDept
#     Center --> SocialDept
#     Center --> MedServ
#
#     %% Администрация
#     Director["Директор"]
#     Method["Методист / Зав. отделением"]
#     Admin --> Director
#     Admin --> Method
#
#     %% Медико-диагностическое отделение
#     Neurologist["Детский невролог"]
#     Orthopedist["Ортопед"]
#     Rehabilitator["Реабилитолог"]
#     MedDiag --> Neurologist
#     MedDiag --> Orthopedist
#     MedDiag --> Rehabilitator
#
#     %% ЛФК
#     LFKDoctor["Врач ЛФК"]
#     Instructors["Инструкторы"]
#     LFK --> LFKDoctor
#     LFK --> Instructors
#
#     %% ТСР и эрготерапия
#     Ergo["Эрготерапевт"]
#     Engineer["Инженер по ТСР"]
#     Consultant["Технический консультант"]
#     TsrDept --> Ergo
#     TsrDept --> Engineer
#     TsrDept --> Consultant
#
#     %% Психолого-педагогическая служба
#     Psychologist["Психолог"]
#     Speech["Логопед / дефектолог"]
#     PsychDept --> Psychologist
#     PsychDept --> Speech
#
#     %% Социально-юридическая служба
#     SocialWorker["Социальный работник"]
#     SocialDept --> SocialWorker
#
#     %% Медицинская служба
#     Nurses["Медсёстры"]
#     CareAssistants["Помощники по уходу"]
#     MedServ --> Nurses
#     MedServ --> CareAssistants
# ```
